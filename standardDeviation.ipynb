# %%
import numpy 

speed = [32,111,138,28,59,77,97]

x= numpy.std(speed )

print(x)
# Out:
# 37.84501153334721

# %%
# for variance 

import numpy 

speed = [11, 22, 33, 12, 34, 55, 30]

x = numpy.var(speed)

print(x)
# Out:
# 196.4081632653061
