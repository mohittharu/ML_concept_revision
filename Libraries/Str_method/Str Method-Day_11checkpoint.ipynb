# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib as plyt

# %%
titanic =pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.drop(columns=['Cabin'], inplace = True)

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic.fillna({'Age': titanic['Age'].median(), 'Embarked': titanic['Embarked'].mode()[0]}, inplace= True )

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # for apply any string method in pandas we need to use.str

# %%
name_length= titanic['Name'].str.len()
name_length
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
# extract data from sting 
titanic['SurName']= titanic['Name'].str.split(',').str.get(0).str.strip()     # white space hatako

# %%
titanic['Name'].str.split(',').str.get(1).str.strip().str.split(' ',n=1) # n ley kati ota paxi denote garxa
# Out:
# 0                                 [Mr., Owen Harris]
# 1      [Mrs., John Bradley (Florence Briggs Thayer)]
# 2                                     [Miss., Laina]
# 3              [Mrs., Jacques Heath (Lily May Peel)]
# 4                               [Mr., William Henry]
#                            ...
# 886                                   [Rev., Juozas]
# 887                          [Miss., Margaret Edith]
# 888                [Miss., Catherine Helen "Carrie"]
# 889                               [Mr., Karl Howell]
# 890                                   [Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
titanic['Name'].str.split(',').str.get(1).str.strip().str.split(' ',n=1 , expand= True) # n ley kati expand  garxa
# Out:
# 0                                 [Mr., Owen Harris]
# 1      [Mrs., John Bradley (Florence Briggs Thayer)]
# 2                                     [Miss., Laina]
# 3              [Mrs., Jacques Heath (Lily May Peel)]
# 4                               [Mr., William Henry]
#                            ...
# 886                                   [Rev., Juozas]
# 887                          [Miss., Margaret Edith]
# 888                [Miss., Catherine Helen "Carrie"]
# 889                               [Mr., Karl Howell]
# 890                                   [Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
titanic[['Title', 'FirstName']]= titanic['Name'].str.split(',').str.get(1).str.strip().str.split(' ',n=1 , expand= True) # n ley kati expand  garxa

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['FirstName'] = titanic['FirstName'].str.strip()

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked    SurName  Title  \
# 0      0         A/5 21171   7.2500        S     Braund    Mr.
# 1      0          PC 17599  71.2833        C    Cumings   Mrs.
# 2      0  STON/O2. 3101282   7.9250        S  Heikkinen  Miss.
# ...

# %% [markdown]
# # find out substring from string

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked    SurName  Title  \
# 0      0         A/5 21171   7.2500        S     Braund    Mr.
# 1      0          PC 17599  71.2833        C    Cumings   Mrs.
# 2      0  STON/O2. 3101282   7.9250        S  Heikkinen  Miss.
# ...

# %%
titanic[titanic['Name'].str.contains('braund', case= False)]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 0              1         0       3    Braund, Mr. Owen Harris  male  22.0
# 477          478         0       3  Braund, Mr. Lewis Richard  male  29.0
#
#      SibSp  Parch     Ticket    Fare Embarked SurName Title      FirstName
# 0        1      0  A/5 21171  7.2500        S  Braund   Mr.    Owen Harris
# 477      1      0       3460  7.0458        S  Braund   Mr.  Lewis Richard

# %%
titanic[titanic['Name'].str.contains('Mr.')]['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
#                              ...
# 883                        Banfield, Mr. Frederick James
# 884                               Sutehall, Mr. Henry Jr
# 885                 Rice, Mrs. William (Margaret Norton)
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 647, dtype: object

# %%
titanic['Sex'].str.replace('male','Male')         # regular expression use garni
# Out:
# 0        Male
# 1      feMale
# 2      feMale
# 3      feMale
# 4        Male
#         ...
# 886      Male
# 887    feMale
# 888    feMale
# 889      Male
# 890      Male
# Name: Sex, Length: 891, dtype: object

# %% [markdown]
# # Date Method

# %%
expense= pd.read_csv('expense_data.csv')
expense.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    NRS Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      NRS       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      NRS      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      NRS       78.0
# 3             Metro   30.0        Expense     NaN    30.0      NRS       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      NRS       67.0

# %%
expense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   NRS             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %% [markdown]
# # data type conversion

# %%
expense['Category'] = expense['Category'].astype('category')
expense.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    NRS Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      NRS       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      NRS      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      NRS       78.0
# 3             Metro   30.0        Expense     NaN    30.0      NRS       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      NRS       67.0
#
#    Year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %% [markdown]
# # string to date time conversion

# %%
expense['Date']= pd.to_datetime(expense['Date'])

# %%
expense['Date']#.dt.year
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 272    2021
# 273    2021
# 274    2021
# 275    2021
# 276    2021
# Name: Date, Length: 277, dtype: int32

# %%
expense['Year']= expense['Date'].dt.year

# %%
expense.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    NRS Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      NRS       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      NRS      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      NRS       78.0
# 3             Metro   30.0        Expense     NaN    30.0      NRS       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      NRS       67.0
#
#    Year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %%
expense['Year'].unique()
# Out:
# array([2022, 2021], dtype=int32)

# %%
expense['Date'].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 272    11
# 273    11
# 274    11
# 275    11
# 276    11
# Name: Date, Length: 277, dtype: int32

# %%
expense['Date'].dt.day
# Out:
# 0       2
# 1       2
# 2       1
# 3       1
# 4       1
#        ..
# 272    22
# 273    22
# 274    21
# 275    21
# 276    21
# Name: Date, Length: 277, dtype: int32

# %%
expense['Date'].dt.hour# ==10
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# Name: Date, Length: 277, dtype: bool
